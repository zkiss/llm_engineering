# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "gemma3:1b"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull llama3.2
# Out:
# zsh:1: command not found: ollama

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Okay, let's dive into the exciting business applications of Generative AI! It's moving beyond just creative content and into areas that fundamentally change how businesses operate. Here's a breakdown of some key applications, categorized for clarity:
#
# **1. Content Creation & Marketing:**
#
# * **Automated Content Generation:** This is arguably the most visible application. Generative AI can create:
#     * **Marketing Copy:**  Product descriptions, ad headlines, email subject lines, social media posts, blog outlines – all at scale and often with a tailored tone.
#     * **Visual Content:**  Generating images, logos, and even short video clips based on text prompts. Tools like DALL-E 2, Midjourney, and Stable Diffusion are already widely used.
#     * **Blog Posts & Articles:**  AI can draft initial drafts, research topics, and even suggest improvements to existing content.
# * **Personalized Marketing:** Generative AI can analyze customer data to create highly personalized marketing campaigns – emails, ads, and product recommendations.
# * **Product Descriptions:** Quickly generate multiple variations of product descriptions for e-commerce sites, optimizing for SEO and conversion.
# * **Brand Voice & Tone Consistency:** Train AI to mimic a brand's established voice and tone across all content.
#
#
# **2. Product Development & Design:**
#
# * **Rapid Prototyping:** Generative AI can create 3D models, UI/UX designs, and even initial product prototypes based on descriptions or sketches. This drastically speeds up the design process.
# * **Generative Design:**  For engineering and product design, AI can explore numerous design options based on specified constraints (weight, cost, performance) and generate optimal solutions.
# * **Material & Component Selection:**  AI can suggest optimal materials and components for a product based on its design and requirements.
# * **Code Generation:** Tools like GitHub Copilot and others are using generative AI to assist developers with writing code – speeding up development cycles and potentially reducing errors.
#
#
# **3. Customer Service & Support:**
#
# * **Chatbots & Virtual Assistants:**  Generative AI powers more sophisticated chatbots that can understand complex queries, provide personalized responses, and even handle basic troubleshooting.
# * **Ticket Summarization & Routing:** AI can quickly summarize customer support tickets and route them to the appropriate agents.
# * **Knowledge Base Creation:**  AI can automatically generate FAQs and documentation based on existing data.
# * **Sentiment Analysis & Response Suggestions:** Analyze customer interactions to identify sentiment and suggest appropriate responses.
#
#
# **4. Sales & Business Intelligence:**
#
# * **Lead Generation & Qualification:** AI can analyze data to identify potential leads and score them based on likelihood of conversion.
# * **Sales Script Generation:**  Generate personalized sales scripts based on the prospect's needs and interests.
# * **Market Research & Trend Analysis:**  Analyze large datasets to identify emerging trends and market opportunities.
# * **Report Generation:** Automate the creation of reports based on data analysis.
# * **Competitive Analysis:**  Generate summaries of competitor activities and strategies.
#
#
# **5. Operations & Efficiency:**
#
# * **Document Summarization:** Quickly summarize lengthy reports, contracts, or legal documents.
# * **Data Augmentation:** Generate synthetic data to expand training datasets for machine learning models.
# * **Automated Report Generation:** Create reports from data sources, reducing manual effort.
# * **Process Automation:**  AI can automate repetitive tasks within workflows.
#
#
# **Specific Examples & Technologies:**
#
# * **ChatGPT & Similar LLMs:**  Excellent for content creation, brainstorming, and answering questions.
# * **DALL-E 2, Midjourney, Stable Diffusion:**  For image generation.
# * **GitHub Copilot:**  AI-powered code completion and generation.
# * **Jasper.ai, Copy.ai:**  Specialized tools for marketing copy and content creation.
# * **Synthesia:**  Creates realistic AI-generated videos from text.
#
#
# **Important Considerations & Challenges:**
#
# * **Bias:** Generative AI models can inherit biases from the data they're trained on.
# * **Hallucinations:**  AI can sometimes generate incorrect or nonsensical information.
# * **Ethical Concerns:**  Misuse of AI for disinformation, deepfakes, and plagiarism is a concern.
# * **Data Privacy & Security:**  Using customer data to train AI models requires careful attention to privacy.
# * **Cost:**  Developing and deploying generative AI solutions can be expensive.
#
#
# **To help me tailor this further, could you tell me:**
#
# *   **What industry are you most interested in?** (e.g., marketing, software development, healthcare, finance?)
# *   **What specific type of business are you focused on?** (e.g., small business, enterprise, e-commerce?)

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Okay, let's dive into the exciting business applications of Generative AI! It's moving beyond just creative content generation and into areas that fundamentally change how businesses operate. Here's a breakdown of some key applications, categorized for clarity:
#
# **1. Content Creation & Marketing:**
#
# * **Automated Content Generation:** This is arguably the most visible application. Generative AI can create:
#     * **Marketing Copy:** Product descriptions, ad headlines, email subject lines, social media posts, blog outlines – all at scale and often with varying tones and styles.
#     * **Visual Content:**  Generating images, logos, and even short video clips based on text prompts. (Think DALL-E 2, Midjourney, Stable Diffusion).
#     * **Website Content:**  Drafting website copy, creating landing page variations, and even generating basic website structure.
# * **Personalized Content:** Tailoring content to individual customers based on their behavior, preferences, and history – leading to higher engagement and conversion rates.
# * **Product Descriptions:** Quickly generating multiple product descriptions for e-commerce sites, saving time and improving SEO.
# * **SEO Optimization:**  Generating keyword variations and content ideas to improve search engine rankings.
#
# **2. Sales & Customer Service:**
#
# * **Lead Generation & Qualification:**  AI can analyze data to identify potential leads based on specific criteria and even generate personalized outreach messages.
# * **Chatbots & Virtual Assistants:**  Generative AI powers more sophisticated chatbots that can handle complex queries, provide personalized recommendations, and even resolve basic issues.  They can understand context and respond more naturally.
# * **Customer Support Ticket Summarization:** Quickly summarizing lengthy customer support tickets to help agents understand the issue faster.
# * **Personalized Email Campaigns:**  Creating email sequences tailored to individual customer segments, increasing open and click-through rates.
# * **Script Generation for Sales Calls:**  Generating scripts for sales calls, ensuring consistent messaging and addressing potential objections.
#
#
# **3. Product Development & Engineering:**
#
# * **Design Generation:**  Creating initial design concepts for products, prototypes, and user interfaces. (Think of tools that suggest variations based on user input).
# * **Code Generation & Completion:**  AI can generate code snippets, complete functions, and even suggest entire code blocks – accelerating the development process. (GitHub Copilot is a prime example).
# * **Testing & Debugging:**  Generating test cases and identifying potential bugs in software.
# * **Simulating Product Performance:**  Creating synthetic data to test and validate product features before real-world deployment.
# * **Drug Discovery & Research:**  Generating novel molecule structures and predicting their properties – a huge area of potential for pharmaceutical companies.
#
#
# **4. Operations & Business Intelligence:**
#
# * **Report Generation:**  Automatically generating reports from data – streamlining data analysis and providing insights.
# * **Financial Modeling:**  Creating financial models and forecasts based on historical data.
# * **Market Research:**  Analyzing large datasets to identify trends and insights.
# * **Supply Chain Optimization:**  Generating scenarios and optimizing supply chain routes.
# * **Risk Assessment:**  Generating risk profiles based on data and identifying potential vulnerabilities.
#
#
# **5. Data Augmentation & Synthetic Data:**
#
# * **Generating Synthetic Data:** Creating realistic synthetic data to train machine learning models, especially when real data is scarce or sensitive. This is crucial for privacy-preserving AI.
# * **Data Enrichment:**  Generating new data points based on existing data to improve the accuracy and completeness of datasets.
#
#
# **Specific Generative AI Models Driving These Applications:**
#
# * **GPT (Generative Pre-trained Transformer) family:** Excellent for text generation, chatbots, and content creation.
# * **DALL-E 2, Midjourney, Stable Diffusion:**  For image generation.
# * **ChatGPT:**  For conversational AI and text-based tasks.
# * **Code Generation Models (GitHub Copilot, etc.):**  For code automation.
#
#
# **Important Considerations & Challenges:**
#
# * **Bias:** Generative AI models can inherit biases from the data they're trained on.
# * **Hallucinations:**  Models can sometimes generate incorrect or nonsensical information.
# * **Ethical Concerns:**  Misinformation, deepfakes, and copyright issues are important considerations.
# * **Cost:**  Developing and deploying generative AI solutions can be expensive.
#
# ---
#
# **To help me tailor this response further, could you tell me:**
#
# *   **What industry are you most interested in?** (e.g., marketing, finance, healthcare, etc.)
# *   **What specific type of business application are you most curious about?** (e.g., content creation, automation, product development?)

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)

# %% [markdown]
# ## Are you confused about why that works?
#
# It seems strange, right? We just used OpenAI code to call Ollama?? What's going on?!
#
# Here's the scoop:
#
# The python class `OpenAI` is simply code written by OpenAI engineers that makes calls over the internet to an endpoint.
#
# When you call `openai.chat.completions.create()`, this python code just makes a web request to the following url: "https://api.openai.com/v1/chat/completions"
#
# Code like this is known as a "client library" - it's just wrapper code that runs on your machine to make web requests. The actual power of GPT is running on OpenAI's cloud behind this API, not on your computer!
#
# OpenAI was so popular, that lots of other AI providers provided identical web endpoints, so you could use the same approach.
#
# So Ollama has an endpoint running on your local box at http://localhost:11434/v1/chat/completions
# And in week 2 we'll discover that lots of other providers do this too, including Gemini and DeepSeek.
#
# And then the team at OpenAI had a great idea: they can extend their client library so you can specify a different 'base url', and use their library to call any compatible API.
#
# That's it!
#
# So when you say: `ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')`
# Then this will make the same endpoint calls, but to Ollama instead of OpenAI.

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1:1.5b

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.
