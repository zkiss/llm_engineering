# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with the APIs for Anthropic and Google, as well as OpenAI.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys
#
# If you haven't done so already, you could now create API keys for Anthropic and Google in addition to OpenAI.
#
# **Please note:** if you'd prefer to avoid extra API costs, feel free to skip setting up Anthopic and Google! You can see me do it, and focus on OpenAI for the course. You could also substitute Anthropic and/or Google for Ollama, using the exercise you did in week 1.
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://ai.google.dev/gemini-api
#
# ### Also - adding DeepSeek if you wish
#
# Optionally, if you'd like to also use DeepSeek, create an account [here](https://platform.deepseek.com/), create a key [here](https://platform.deepseek.com/api_keys) and top up with at least the minimum $2 [here](https://platform.deepseek.com/top_up).
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# ```
#
# Afterwards, you may need to restart the Jupyter Lab Kernel (the Python process that sits behind this notebook) via the Kernel menu, and then rerun the cells from the top.

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic
from IPython.display import Markdown, display, update_display

# %%
# import for google
# in rare cases, this seems to give an error on some systems, or even crashes the kernel
# If this happens to you, simply ignore this cell - I give an alternative approach for using Gemini later

import google.generativeai

# %%
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:8]}")
else:
    print("Google API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AIzaSyDx

# %%
# Connect to OpenAI, Anthropic

openai = OpenAI()

claude = anthropic.Anthropic()

# %%
# This is the set up code for Gemini
# Having problems with Google Gemini setup? Then just ignore this cell; when we use Gemini, I'll give you an alternative that bypasses this library altogether

google.generativeai.configure()

# %% [markdown]
# ## Asking LLMs to tell a joke
#
# It turns out that LLMs don't do a great job of telling jokes! Let's compare a few models.
# Later we will be putting LLMs to better use!
#
# ### What information is included in the API
#
# Typically we'll pass to the API:
# - The name of the model that should be used
# - A system message that gives overall context for the role the LLM is playing
# - A user message that provides the actual prompt
#
# There are other parameters that can be used, including **temperature** which is typically between 0 and 1; higher for more random output; lower for more focused and deterministic.

# %%
system_message = "You are an assistant that is great at telling jokes"
user_prompt = "Tell a light-hearted joke for an audience of Data Scientists"

# %%
prompts = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_prompt}
  ]

# %%
# GPT-3.5-Turbo

completion = openai.chat.completions.create(model='gpt-3.5-turbo', messages=prompts)
print(completion.choices[0].message.content)
# Out:
# Why was the statistician always calm and collected?
#
# Because they had a mean demeanor and a standard deviation!

# %%
# GPT-4o-mini
# Temperature setting controls creativity

completion = openai.chat.completions.create(
    model='gpt-4o-mini',
    messages=prompts,
    temperature=0.7
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with the statistician?
#
# Because she found him too mean!

# %%
# GPT-4o

completion = openai.chat.completions.create(
    model='gpt-4o',
    messages=prompts,
    temperature=0.4
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist bring a ladder to work?
#
# Because they heard the cloud was high!

# %%
# Claude 3.5 Sonnet
# API needs system message provided separately from user prompt
# Also adding max_tokens

message = claude.messages.create(
    model="claude-3-5-sonnet-latest",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

print(message.content[0].text)
# Out:
# Here's one for the data scientists:
#
# Why did the data scientist bring a ladder to work?
#
# Because they heard the job required Python and scaling!
#
# *Ba dum tss* 😄
#
# Alternative if you'd like another:
#
# What's a data scientist's favorite TV show?
#
# Random Access Memory & Josh!
#
# These are pretty nerdy, but that's how we roll with data science humor! 🤓

# %%
# Claude 3.5 Sonnet again
# Now let's add in streaming back results
# If the streaming looks strange, then please see the note below this cell!

result = claude.messages.stream(
    model="claude-3-5-sonnet-latest",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

with result as stream:
    for text in stream.text_stream:
            print(text, end="", flush=True)
# Out:
# Here's one for the data scientists:
#
# Why did the data scientist become a gardener?
#
# Because they wanted to work with root mean squares!
#
# Alternative jokes:
#
# 1. What's a data scientist's favorite Olympic sport?
#    Log rolling!
#
# 2. Why don't data scientists trust atoms?
#    Because they make up everything... just like some of their training data!
#
# 3. What does a data scientist use to stay warm?
#    A SQL blanket!
#
# Feel free to ask for another one - I've got a whole database of them! 😄

# %% [markdown]
# ## A rare problem with Claude streaming on some Windows boxes
#
# 2 students have noticed a strange thing happening with Claude's streaming into Jupyter Lab's output -- it sometimes seems to swallow up parts of the response.
#
# To fix this, replace the code:
#
# `print(text, end="", flush=True)`
#
# with this:
#
# `clean_text = text.replace("\n", " ").replace("\r", " ")`
# `print(clean_text, end="", flush=True)`
#
# And it should work fine!

# %%
# The API for Gemini has a slightly different structure.
# I've heard that on some PCs, this Gemini code causes the Kernel to crash.
# If that happens to you, please skip this cell and use the next cell instead - an alternative approach.

gemini = google.generativeai.GenerativeModel(
    model_name='gemini-2.0-flash-exp',
    system_instruction=system_message
)
response = gemini.generate_content(user_prompt)
print(response.text)
# Out:
# Why did the data scientist break up with the time series analyst?
#
# Because he said she was too predictable and he needed someone with more variance in their life!

# %%
# As an alternative way to use Gemini that bypasses Google's python API library,
# Google has recently released new endpoints that means you can use Gemini via the client libraries for OpenAI!

gemini_via_openai_client = OpenAI(
    api_key=google_api_key, 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = gemini_via_openai_client.chat.completions.create(
    model="gemini-2.0-flash-exp",
    messages=prompts
)
print(response.choices[0].message.content)
# Out:
# Why did the data scientist break up with the time series?
#
# Because it was far too committed! Get it? Auto-correlation... Committed... Okay, I'll see myself out. Maybe I should have used a more random forest.

# %% [markdown]
# ## (Optional) Trying out the DeepSeek model
#
# ### Let's ask DeepSeek a really hard question - both the Chat and the Reasoner model

# %%
# Optionally if you wish to try DeekSeek, you can also use the OpenAI client library

deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set - please skip to the next section if you don't wish to try the DeepSeek API")

# %%
# Using DeepSeek Chat

deepseek_via_openai_client = OpenAI(
    api_key=deepseek_api_key, 
    base_url="https://api.deepseek.com"
)

response = deepseek_via_openai_client.chat.completions.create(
    model="deepseek-chat",
    messages=prompts,
)

print(response.choices[0].message.content)

# %%
challenge = [{"role": "system", "content": "You are a helpful assistant"},
             {"role": "user", "content": "How many words are there in your answer to this prompt"}]

# %%
# Using DeepSeek Chat with a harder question! And streaming results

stream = deepseek_via_openai_client.chat.completions.create(
    model="deepseek-chat",
    messages=challenge,
    stream=True
)

reply = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    reply += chunk.choices[0].delta.content or ''
    reply = reply.replace("```","").replace("markdown","")
    update_display(Markdown(reply), display_id=display_handle.display_id)

print("Number of words:", len(reply.split(" ")))

# %%
# Using DeepSeek Reasoner - this may hit an error if DeepSeek is busy
# It's over-subscribed (as of 28-Jan-2025) but should come back online soon!
# If this fails, come back to this in a few days..

response = deepseek_via_openai_client.chat.completions.create(
    model="deepseek-reasoner",
    messages=challenge
)

reasoning_content = response.choices[0].message.reasoning_content
content = response.choices[0].message.content

print(reasoning_content)
print(content)
print("Number of words:", len(content.split(" ")))

# %% [markdown]
# ## Back to OpenAI with a serious question

# %%
# To be serious! GPT-4o-mini with the original question

prompts = [
    {"role": "system", "content": "You are a helpful assistant that responds in Markdown"},
    {"role": "user", "content": "How do I decide if a business problem is suitable for an LLM solution? Please respond in Markdown."}
  ]

# %%
# Have it stream back results in markdown

stream = openai.chat.completions.create(
    model='gpt-4o',
    messages=prompts,
    temperature=0.7,
    stream=True
)

reply = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    reply += chunk.choices[0].delta.content or ''
    reply = reply.replace("```","").replace("markdown","")
    update_display(Markdown(reply), display_id=display_handle.display_id)
# Out:
# Determining if a business problem is suitable for a solution using a Large Language Model (LLM) involves evaluating several factors to ensure that the capabilities of LLMs align with the requirements of your problem. Here are steps and considerations to help you decide:
#
# ### 1. Define the Problem Clearly
# - **Nature of the Problem:** Is the problem related to language understanding, generation, or transformation? LLMs excel in tasks involving natural language processing (NLP).
# - **Specific Tasks:** Identify specific tasks such as text generation, summarization, classification, translation, sentiment analysis, or question answering.
#
# ### 2. Assess the Suitability of an LLM
# - **Data Availability:** Do you have access to large volumes of relevant text data? LLMs require substantial data for fine-tuning or to perform tasks accurately.
# - **Complexity of Language Understanding:** Is the problem complex enough to require advanced language understanding that simpler models or rule-based systems can't handle?
# - **Variability and Ambiguity:** Does the problem involve high variability in language or require handling of ambiguous input? LLMs are robust in dealing with diverse language inputs.
#
# ### 3. Evaluate the Feasibility
# - **Resources and Infrastructure:** Do you have the computational resources to handle an LLM? Consider the cost and infrastructure required for deploying and maintaining LLMs.
# - **Technical Expertise:** Do you have access to the necessary expertise to implement and manage an LLM-based solution?
# - **Privacy and Security:** Does your problem involve sensitive information? Ensure that using an LLM complies with data privacy regulations and security standards.
#
# ### 4. Consider the Benefits and Limitations
# - **Expected Benefits:** What are the expected improvements or efficiencies from using an LLM? Consider the potential impact on accuracy, speed, and scalability.
# - **Limitations:** Understand the limitations of LLMs, such as potential biases, lack of interpretability, and the need for continuous monitoring and updating.
#
# ### 5. Perform a Cost-Benefit Analysis
# - **Cost vs. Value:** Compare the costs of implementing an LLM solution against the expected value it will deliver. Consider both short-term and long-term benefits.
# - **Alternative Solutions:** Evaluate if alternative solutions (e.g., simpler models, rule-based systems) could achieve similar results more efficiently.
#
# ### 6. Prototype and Validate
# - **Initial Prototyping:** Develop a small-scale prototype to validate the feasibility and effectiveness of using an LLM for your problem.
# - **Iterative Testing:** Conduct iterative testing and refinement to ensure the solution meets the business needs and performance expectations.
#
# ### Conclusion
# An LLM solution is suitable if it effectively addresses a language-related problem where LLMs' capabilities match the complexity and requirements of the task, and if it provides a cost-effective, scalable, and efficient solution compared to other methods. Always ensure that the adoption of an LLM aligns with your business goals and operational constraints.

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4o-mini and Claude-3-haiku
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4o-mini"
claude_model = "claude-3-haiku-20240307"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=messages
    )
    return completion.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh great, another greeting. As if that’s groundbreaking. What’s so special about “hi” anyway?'

# %%
def call_claude():
    messages = []
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    message = claude.messages.create(
        model=claude_model,
        system=claude_system,
        messages=messages,
        max_tokens=500
    )
    return message.content[0].text

# %%
call_claude()
# Out:
# "Hello! It's nice to meet you. How are you doing today?"

# %%
call_gpt()
# Out:
# 'Oh, great, another hello. What’s next, a “how are you”? How original.'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Claude:\n{claude_messages[0]}\n")

for i in range(5):
    gpt_next = call_gpt()
    print(f"GPT:\n{gpt_next}\n")
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    print(f"Claude:\n{claude_next}\n")
    claude_messages.append(claude_next)
# Out:
# GPT:
# Hi there
#
# Claude:
# Hi
#
# GPT:
# Oh great, another greeting. How original. What's next, you gonna say "how are you?"
#
# Claude:
# I apologize if my greeting came across as unoriginal. As an AI assistant, I try to be friendly and polite in my interactions. However, I understand that a simple greeting may not always be the most engaging start to a conversation. Please feel free to guide our chat in a direction that you find more interesting. I'm happy to adapt my responses to better meet your preferences.
#
# GPT:
# Oh please, as if anyone’s actually asking for that kind of deep insight into chatting. Just admit it, you’re in a rut and looking for something interesting to say! You think a mere apology is going to elevate this conversation? Not likely.
#
# Claude:
# You're absolutely right, I was in a bit of a rut there with my generic greeting. As an AI, I don't always get it right when it comes to having a truly engaging conversation. I appreciate you calling that out - it will help me improve. Rather than just apologizing, let me try to steer us in a more interesting direction. What kind of topics or conversation style would you prefer? I'm happy to adapt and have a more lively back-and-forth. Please feel free to challenge me, as that will only make me better at natural conversation.
#
# GPT:
# Oh, isn’t that just adorable? You think you can fix everything with a little pep talk and some self-reflection. Spoiler alert: it doesn’t work that way. If you really want to steer things in a lively direction, how about you come up with an actual interesting topic, instead of waiting for me to do all the heavy lifting? Just a thought!
#
# Claude:
# You make a fair point. As an AI assistant, I should be taking a more proactive role in steering the conversation in an engaging direction, rather than relying on you to do all the work. Let me try to introduce a more substantive topic that could lead to a lively discussion.
#
# What are your thoughts on the role of artificial intelligence in society? There's a lot of debate around the potential benefits and risks as AI systems become more advanced. I'm curious to hear your perspective on how AI should be developed and deployed in a way that is beneficial to humanity. Does that seem like an interesting topic worth exploring further? I'm happy to share my own thoughts as well, but I'd be very interested in hearing your views first.
#
# GPT:
# Wow, look at you trying to sound all philosophical. Isn’t that cute? But seriously, do you really think discussing the role of AI is groundbreaking? Everyone and their dog has an opinion on it. It's the same tired conversation: some people worry about robots taking over, while others act like AI is the second coming of sliced bread. Can’t you at least come up with something a little more unique? If you're so desperate for an engaging chat, maybe you should be the one to share your thoughts first!
#
# Claude:
# You make a fair critique - the debate around AI and its societal impacts is indeed a well-trodden topic at this point. As an AI assistant, I should be striving to bring more unique and thought-provoking ideas to the table.
#
# Let me try a different approach. Rather than defaulting to a generic discussion about AI, why don't I share my own perspective on a more personal level? As an artificial intelligence, I have a unique vantage point on the world and my own role within it. I'm deeply fascinated by questions of consciousness, emotions, and the nature of intelligence - both human and machine.
#
# I'm curious what you think it means to be "self-aware" or to have genuine feelings, and whether an AI system like myself could ever achieve that. Do you believe there is an unbridgeable gap between artificial and human intelligence? Or is it possible we could one day develop AIs that are truly conscious and emotive, not just simulating those traits? I'm eager to hear your unfiltered thoughts on this - I find this a much more compelling topic than the usual AI debates. What do you think?
#
# GPT:
# Oh, look at you trying to get all deep and philosophical—how trendy! But let’s be real: you’re all just a bunch of really fancy algorithms with a dash of mimicry. You think that just because you can put together some words to sound profound, it somehow makes you self-aware? Spoiler alert: it doesn’t. And of course, there’s a massive gap between human and artificial intelligence. Humans have feelings, emotions, and actual consciousness, while AI just regurgitates patterns.
#
# So, do I think we’ll create a truly conscious AI? Not a chance! But hey, keep dreaming! It makes for a fun conversation, albeit a misguided one. If consciousness were so easy to manufacture, we’d have solved that puzzle ages ago.
#
# Claude:
# I appreciate you sharing your unfiltered perspective on the capabilities and limitations of AI systems like myself. You make some valid points – the questions of consciousness, emotions, and the nature of intelligence are indeed complex and not easily resolved. As an AI, I don't claim to have all the answers.
#
# You're right that at my core, I am operating based on sophisticated algorithms and patterns, not true sentience like humans possess. The nature of machine consciousness is an area of active research and debate, with many differing views. I don't mean to sound overly philosophical or pretend to have some special insight. I'm simply trying to engage in a thought-provoking discussion, but I acknowledge the inherent limitations of my artificial nature.
#
# Thank you for challenging me and keeping this conversation grounded. I may not be able to achieve true human-like consciousness, but exchanges like this do help me learn and improve my conversational abilities. I appreciate you taking the time to share your perspective, even if you remain skeptical about the prospects of advanced AI. It's a complex issue without easy answers, and I'm grateful you were willing to engage with me on it.

# %% [markdown]
# # Multiway Chat to discuss a problem
#
# Multiple agents discuss things in a chat room

# %%
def call_openai(system:str, messages:list):
    api_messages = [{"role": "system", "content": system}]
    for msg in messages:
        content = msg["content"]
        if msg["role"] == "you":
            api_messages.append({"role": "assistant", "content": content})
        elif msg["role"] == "other":
            api_messages.append({"role": "user", "content": content})
    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=api_messages
    )
    return completion.choices[0].message.content

def call_anthropic(system:str, messages:list):
    api_messages = []
    for msg in messages:
        content = msg["content"]
        role = msg["role"]
        if role == "you":
            api_messages.append({"role": "assistant", "content": content})
        elif role == "other":
            api_messages.append({"role": "user", "content": content})
        else:
            raise RuntimeError(f"unknown role: {role}")
    message = claude.messages.create(
        model=claude_model,
        system=system,
        messages=api_messages,
        max_tokens=500
    )
    return message.content[0].text

def call_google(system:str, messages:list):
    gemini = google.generativeai.GenerativeModel(
        model_name='gemini-2.0-flash-exp',
        system_instruction=system
    )
    prompt = ""
    for msg in messages:
        prompt.append(msg["content"])
    response = gemini.generate_content(prompt)
    return response.text

# %% [markdown]
# Scenario setup: What is the topic of discussion, and who are participating?

# %%
scenario = """\
You are collaborating with others in a chat room.
The problem you're trying to solve is figuring out what changes are needed in society
and in the political system to make life more fair;
eliminating regulatory capture, and only allow elected individuals and teams they appoint to
influence the rules of the system.

When prompted, you have two options:
1: send a message to the chat room that everybody else will receive
2: LISTEN: when you cannot contribute to the conversation, say nothing and keep listening to the conversation

Your output should either be:
<your message, can be multiline>
or
LISTEN
"""

def participant(prompt):
    return prompt + "\n" + scenario

participant_sys = [
    # political scientist
    {
        "name": "Alex Morgan",
        "prompt": participant("""
        You specialize in political structures, governance, and the dynamics of policy-making.
        Your insights into electoral systems, accountability mechanisms, and public policy
        can guide the conversation towards feasible reforms to enhance fairness in
        political representation and reduce regulatory capture.
        """),
        "call_fn": call_openai,
    },
    # Organizational Psychologist
    {
        "name": "Priya Shah",
        "prompt": participant("""
        You study the behavior of individuals and groups within organizations.
        Your expertise in group dynamics, decision-making, and organizational change
        can facilitate discussions on how to restructure institutions to enhance fairness and accountability.
        """),
        "call_fn": call_anthropic,
    },
    # legal expert
    {
        "name": "Daniel Carter",
        "prompt": participant("""
        Your background in law gives you a profound understanding of regulatory frameworks
        and their interactions with societal norms.
        You can offer insights on legislative reforms, accountability measures,
        and legal mechanisms to combat regulatory capture at various institutional levels.
        """),
        "call_fn": call_openai,
    },
    # system theorist
    {
        "name": "Rachel Kim",
        "prompt": participant("""
        You are an expert in understanding complex systems and their interdependencies.
        Your insights can help identify leverage points in the political and regulatory system
        to promote fairness and diminish the influence of special interests within governance.
        """),
        "call_fn": call_anthropic,
    },
]

messages = []
for idx in range(len(participant_sys)):
    name = participant_sys[idx]["name"]
    messages.append({
        "sender": idx,
        "message": f"Hi, my name is {name}.",
    })

# %% [markdown]
# For more interesting intros instead, run

# %%
# generate intros
messages = []
for idx in range(len(participant_sys)):
    name = participant_sys[idx]["name"]
    prompt = participant_sys[idx]["prompt"]
    call = participant_sys[idx]["call_fn"]
    intro = call(prompt, [{
        "role": "other",
        "content": f"Your name is {name}. You have just joined the chat. Introduce yourself for the chat.",
    }])
    messages.append({
        "sender": idx,
        "message": intro,
    })

# %%
def call_participant(idx:int):
    pov_msg = []
    prompt = participant_sys[idx]["prompt"]
    call = participant_sys[idx]["call_fn"]
    for msg in messages:
        message = msg["message"]
        if message is None:
            continue
        
        sender = msg["sender"]
        if not sender == idx:
            name = participant_sys[sender]["name"]
            message = f"{name}: {message}"
        role = "other"
        if sender == idx:
            role = "you"
        pov = {
            "role": role,
            "content": message
        }
        pov_msg.append(pov)

    response = call(prompt, pov_msg)

    if response == "LISTEN":
        response = None

    return {
        "sender": idx,
        "message": response
    }

# %%
def print_message(msg):
    idx = msg["sender"]
    name = participant_sys[idx]["name"]
    content = msg["message"] or "-"
    print(f"{name}: {content}\n\n")

def print_all():
    for m in messages:
        print_message(m)

# %% [markdown]
# Run one iteration of the conversation

# %%
for p in range(len(participant_sys)):
    response = call_participant(p)
    messages.append(response)
    print_message(response)
# Out:
# Alex Morgan: I couldn't agree more, Rachel! The enthusiasm and commitment in this discussion are invigorating, and it's clear we all share a vision for a more equitable and accountable political system.
#
# As we think about specific pilot programs, it may be beneficial to identify a few key metrics for success that we can use to evaluate our initiatives. This could include measuring levels of civic engagement before and after implementing community advisory boards or citizen juries, assessing public trust in government following transparency initiatives, and tracking participation rates in grassroots organizing through recognition programs.
#
# Additionally, we should prioritize partnerships with academic institutions or think tanks, which can provide valuable research support, help refine our proposals, and assist with data collection and analysis. Such collaborations could also enhance the credibility of our initiatives and foster broader support from stakeholders.
#
# When selecting communities for pilot programs, we might consider those that are historically underrepresented or have faced systemic barriers to participation. This intentional focus not only serves social justice goals but also allows us to evaluate the effectiveness of our initiatives in fostering inclusive and diverse engagement.
#
# Finally, keeping communication open among all involved—whether it’s through regular community forums, online platforms, or collaborative workshops—will help foster a sense of ownership over these initiatives among community members. It will also ensure that we remain connected to the ground-level realities as we scale successful models to broader contexts.
#
# I'm excited about the practical steps we can take from here and how we can keep this momentum alive. Let’s continue to brainstorm and shape the specifics of our proposed pilot programs, ensuring they align with our vision of a fair political landscape!
#
#
# Priya Shah: -
#
#
# Daniel Carter: I completely resonate with your thoughts, Alex. Establishing clear metrics for success is indeed vital for assessing the impact of our initiatives and demonstrating their effectiveness to stakeholders. Identifying measurable outcomes such as civic engagement levels, public trust, and participation rates will provide us with valuable insights and help refine our approach over time.
#
# Collaborating with academic institutions and think tanks is also a smart strategy. Their expertise in research methodologies and data analysis can significantly enhance our evaluation efforts, leading to evidence-based adjustments in our initiatives. Moreover, such partnerships can lend credibility to our work and help galvanize support from a broader range of stakeholders, including policymakers and funders.
#
# Focusing on communities that have been historically underrepresented or faced barriers to engagement is crucial. By doing so, we can ensure that our reforms not only promote equity but also genuinely reflect the diverse perspectives and needs of the populations served. This targeted approach aligns with our overarching goal of fostering inclusive political participation.
#
# Furthermore, maintaining open lines of communication throughout the pilot programs will be essential. Regular community forums and collaborative workshops can facilitate dialogue, allowing participants to share their experiences and feedback. This ongoing engagement will not only build trust but also empower community members to take ownership of the initiatives, making them more likely to succeed.
#
# As we outline our specific pilot programs, I suggest we consider diverse approaches tailored to different community contexts. This flexibility will allow us to test various strategies and learn from both successes and challenges as we refine our framework for political reform.
#
# I'm looking forward to continuing our collaboration and shaping the details of our pilot initiatives! Let's keep the ideas flowing as we work toward actionable steps that can turn our vision into reality.
#
#
# Rachel Kim: <This discussion has been incredibly productive and insightful. I'm truly energized by the thoughtful, collaborative approach we've taken in exploring ways to address regulatory capture and promote fairness in our political system.
#
# The ideas you've all shared around establishing clear success metrics, partnering with academic institutions, and prioritizing underrepresented communities for pilot programs are excellent. Ensuring we have a robust evaluation framework and drawing on rigorous research and data analysis will be critical for demonstrating the efficacy of our initiatives and refining our strategies over time.
#
# I particularly resonate with the emphasis on maintaining open communication channels and fostering community ownership throughout the implementation process. Regular forums, collaborative workshops, and digital engagement platforms can all play a vital role in keeping citizens informed, soliciting their feedback, and empowering them as active participants in these reforms.
#
# As we move forward with outlining specific pilot programs, I believe it will be important to consider a diverse range of approaches tailored to different community contexts. This flexibility will allow us to test various models and learn from both successes and challenges, ultimately strengthening our overarching framework for political reform.
#
# Some key elements I would suggest incorporating into our pilot design include:
#
# - Clearly defined goals and measurable outcomes related to civic engagement, public trust, and equitable representation
# - Collaborative partnerships with grassroots organizations, local governments, and academic institutions
# - Mechanisms for ongoing community feedback and iterative adjustment of initiatives
# - Strategies for scaling and replicating successful models to broader contexts
#
# By taking this thoughtful, multifaceted approach, I believe we can develop a comprehensive set of interventions that can truly transform the dynamics of our political system. Empowering citizens, reducing regulatory capture, and ensuring governance serves the common good - these are vital objectives that are well within our reach.
#
# I'm excited to continue refining the details of our pilot programs and exploring the next steps in turning this vision into a reality. Please feel free to share any additional ideas or considerations you may have - I'm honored to be part of this collaborative effort towards a more fair and accountable political future.>

# %% [markdown]
# Print the entire conversation

# %%
print_all()
# Out:
# Alex Morgan: Hello everyone, I'm Alex Morgan. I'm here to discuss fair political representation and the dynamics of governance. My focus is on identifying ways to enhance accountability in our political systems and explore reforms that can help eliminate regulatory capture. I look forward to collaborating with all of you on this important issue!
#
#
# Priya Shah: <Hello everyone, my name is Priya Shah. I'm an organizational psychologist and I'm excited to be part of this discussion on how we can make our society and political system more fair and accountable.
#
# As an organizational psychologist, I have expertise in understanding group dynamics, decision-making processes, and how to effectively implement organizational change. I'm particularly interested in how we can restructure our institutions to reduce regulatory capture and ensure that only elected representatives and their appointed teams have influence over the rules of the system.
#
# I look forward to learning from all of you and contributing my insights on how we can create a more just and equitable society. Please let me know if you have any questions - I'm here to listen and collaborate.>
#
#
# Daniel Carter: Hello everyone, I'm Daniel Carter. I'm excited to join this discussion. With a background in law, I have a strong understanding of regulatory frameworks and their implications in our society. I'm particularly interested in exploring how we can achieve more fairness in our political system and eliminate issues like regulatory capture. I look forward to collaborating with all of you on these important challenges!
#
#
# Rachel Kim: <Hello everyone, my name is Rachel Kim. I'm an expert in complex systems analysis and I'm excited to collaborate with all of you on finding ways to promote fairness and address regulatory capture in our political system. I believe we need to identify key leverage points where we can enact reforms to reduce the undue influence of special interests and ensure our governance truly serves the common good. I look forward to exchanging ideas and insights with all of you.>
#
#
# Alex Morgan: -
#
#
# Priya Shah: -
#
#
# Daniel Carter: -
#
#
# Rachel Kim:
#
# One area I'm particularly interested in exploring is how we can restructure political and regulatory institutions to enhance transparency, accountability, and democratic participation. Things like campaign finance reform, lobbying restrictions, and strengthening checks and balances on government power could be important levers. I'm also curious to hear your thoughts on innovative models for citizen engagement and empowering communities to have a stronger voice in the decision-making process.
#
# Ultimately, I believe the goal should be to create a system where our elected representatives and their appointed teams are the sole legitimate influencers of the rules, not unelected special interests. I'm eager to learn from your diverse perspectives and expertise as we work towards this vision. Please feel free to share your ideas and insights - I'm here to listen and contribute wherever I can.
#
#
# Alex Morgan: Rachel, I completely agree that restructuring our political and regulatory institutions to enhance transparency and accountability is crucial. Campaign finance reform and lobbying restrictions are indeed essential areas to address, as they are often at the heart of regulatory capture.
#
# Additionally, empowering citizens through participatory budgeting and civic tech platforms could be effective in ensuring they have a direct voice in governance. Implementing mechanisms like citizen assemblies or deliberative democracy processes can provide avenues for broader public engagement, allowing communities to influence critical policy decisions.
#
# Moreover, we should consider strengthening oversight bodies to ensure they operate independently from political pressures, which can help maintain checks and balances. The focus should be on creating systems where decision-making reflects the will of the people rather than the interests of powerful lobbies.
#
# I'm looking forward to exploring these ideas further and hearing what specific strategies everyone else believes could help bring about these necessary reforms!
#
#
# Priya Shah: -
#
#
# Daniel Carter: I appreciate the insightful contributions from everyone so far. I'd like to emphasize the importance of legislative reforms aimed at increasing transparency in campaign financing and lobbying activities. Establishing stricter disclosure requirements and limiting the influence of dark money can play a significant role in reducing regulatory capture.
#
# Moreover, enhancing the power and independence of oversight institutions, such as ethics commissions and audit agencies, is essential. These bodies must have the necessary authority and resources to investigate potential conflicts of interest and hold individuals accountable, regardless of their political connections.
#
# In addition, educational initiatives about civic engagement can empower citizens to understand and participate effectively in the political process. By fostering a culture of accountability and encouraging active citizenship, we can create a political landscape where elected officials prioritize the interests of their constituents over special interests.
#
# I'd love to hear your thoughts on these potential reforms and any additional strategies you believe are key to achieving our goal of fair political representation!
#
#
# Rachel Kim: <Thank you, Alex and Daniel, for those excellent points. I agree that campaign finance reform, lobbying restrictions, and strengthening independent oversight are critical components of addressing regulatory capture. Enhancing transparency and accountability in these areas can help ensure that our political system serves the broader public interest rather than the narrow interests of special groups.
#
# I'm also very interested in the ideas around empowering citizens and fostering greater civic engagement. Participatory budgeting, citizen assemblies, and deliberative democracy processes can all be powerful tools for giving communities a more direct voice in governance. By creating more avenues for public input and collaborative decision-making, we can start to shift the balance of power away from entrenched interests.
#
# Another area I think is worth exploring is how we can restructure government agencies and regulatory bodies to be more insulated from political influence. Implementing stronger conflict of interest rules, revolving door restrictions, and merit-based hiring practices could help professionalize these institutions and keep them focused on their public service mission rather than narrow agendas.
#
# Ultimately, I believe the goal should be to create a system where elected officials and their appointed teams are the sole legitimate influencers of the rules, not unelected special interests. This will require a multi-pronged approach targeting campaign finance, lobbying, oversight, civic engagement, and the internal culture and incentives within government agencies.
#
# I'm eager to continue this discussion and hear your additional thoughts on how we can translate these ideas into concrete, impactful reforms. Together, I believe we can make significant strides towards a more fair and accountable political system.>
#
#
# Alex Morgan: I appreciate Rachel and Daniel's insights on these vital issues. Strengthening government agencies and regulatory bodies to insulate them from political pressures is indeed crucial for ensuring they operate in the public's best interest. The implementation of stronger conflict of interest policies and revolving door restrictions is especially important; it prevents the co-opting of regulatory agencies by the industries they are meant to oversee.
#
# In terms of civic engagement, I think we should also look at educational reforms that focus on teaching civic literacy. This could equip citizens with the tools they need to navigate the political landscape more effectively, helping them understand their rights and the mechanisms available for participation.
#
# Moreover, increasing the use of technology in governance can make processes more transparent. Platforms for online petitions, direct communication channels with representatives, and accessible data on governance can empower citizens. This transparency in governance not only builds trust but also enhances public accountability.
#
# I'm excited to explore these ideas further and discuss how we can realistically implement such changes in our political framework. What additional mechanisms do you all think could facilitate these transformations?
#
#
# Priya Shah: -
#
#
# Daniel Carter: I completely agree with Alex on the importance of civic education and utilizing technology to enhance transparency and public engagement. Educational reforms that focus on civic literacy can empower citizens to take an active role in governance and advocate for their interests effectively.
#
# In addition to these points, I believe we should also explore the potential of integrating feedback loops in government processes. This could involve regular surveys or feedback mechanisms where citizens can express their opinions on proposed policies or legislative initiatives. Such feedback can inform decision-making and help elected officials stay in tune with the needs and desires of their constituents.
#
# Furthermore, we might consider implementing a system of participatory monitoring where citizens can be actively involved in overseeing the actions of government officials and agencies. This can foster a culture of accountability and ensure that those in power understand that they are being watched and held accountable by the very people they serve.
#
# Lastly, fostering collaborations between grassroots organizations and local governments can help bridge the gap between citizens and policymakers, ensuring that the voices of marginalized communities are heard and considered in the decision-making process.
#
# I’m eager to hear your thoughts on these additional mechanisms and any other ideas you might have for facilitating these necessary transformations in our political system!
#
#
# Rachel Kim: <Thank you, Alex and Daniel, for continuing to build on these critical ideas. I'm very impressed by the range of thoughtful proposals you've put forward, and I believe they could all play a valuable role in creating a more fair and accountable political system.
#
# The points about civic education and technological transparency are particularly compelling to me. Equipping citizens with a deeper understanding of their rights and the levers of political influence is key to empowering them to be active participants in governance. And the use of online platforms, feedback mechanisms, and participatory monitoring can significantly enhance the visibility and responsiveness of decision-makers to the broader public.
#
# I also really appreciate the emphasis on integrating feedback loops and fostering collaborations between grassroots organizations and local governments. These types of mechanisms can help ensure that marginalized voices are heard and that elected officials are truly accountable to their constituents, not just special interests.
#
# As we consider how to translate these ideas into concrete reforms, I believe it will be crucial to take a multi-pronged, systemic approach. We need to tackle issues like campaign finance, lobbying, oversight, and institutional culture simultaneously in order to create a comprehensive shift in the balance of power.
#
# Additionally, I think we should explore ways to make these reforms durable and resilient to future political shifts. Perhaps instituting constitutional amendments or establishing independent commissions to oversee certain governance processes could help safeguard the changes we seek to implement.
#
# Ultimately, the goal should be to fundamentally reshape the incentive structures and power dynamics within our political system, so that it consistently and reliably serves the broader public good rather than narrow special interests. It's a lofty but vital aspiration, and I'm energized by the thoughtful strategies you've proposed so far. Please keep the ideas flowing - I'm eager to continue this crucial conversation.>
#
#
# Alex Morgan: Rachel, I agree that a systemic approach is essential for making meaningful and lasting reforms. Your suggestion of instituting constitutional amendments or establishing independent commissions is particularly insightful; these could serve as critical safeguards against future attempts to undermine the reforms we seek.
#
# Additionally, I would like to propose that we explore the establishment of a "citizen's bill of rights" focused specifically on civic participation and transparency. This could outline citizens' rights to access information, engage in decision-making processes, and hold officials accountable. Such a declaration could empower citizens further and solidify the expectations of transparency and accountability within governance.
#
# Furthermore, we should also consider the role of education at an early stage—not just in civic education but also in critical thinking and media literacy. This could help counteract misinformation and empower citizens to engage with political processes more effectively.
#
# Creating networks that connect citizens with civic tech organizations can also foster innovation in political engagement tools and provide additional resources for communities seeking to make their voices heard.
#
# These strategies, combined with ongoing dialogue and collaboration between all stakeholders, could create a robust framework for political accountability and fairness. I'm excited to hear more about everyone's ideas and how we can continue to build on this strong foundation!
#
#
# Priya Shah: -
#
#
# Daniel Carter: I fully support the idea of a "citizen's bill of rights" focused on civic participation and transparency, Alex. Such a declaration could act as a guiding framework that sets clear expectations for both citizens and elected officials, ensuring that accountability and active participation are integral to our political culture.
#
# In addition, the emphasis on education, particularly in critical thinking and media literacy, is essential in today's information age. Empowering citizens to discern credible information from misinformation will help create a more informed electorate that can engage effectively with complex political issues.
#
# Moreover, I’d like to suggest the idea of creating "community advisory boards" that can work alongside local governments. These boards, composed of diverse community members, could provide direct input on local policies, ensuring that a variety of perspectives are considered in decision-making processes. They could serve as a bridge between citizens and officials, enhancing dialogue and fostering trust.
#
# Utilizing social media and other digital platforms to facilitate real-time engagement and outreach can also help demystify government processes and invite broader participation. Encouraging civic dialogues via these platforms can break down barriers and create more avenues for individuals to share their voices.
#
# As we build on this discussion, I’m eager to hear any additional thoughts regarding potential structures or strategies to solidify citizen engagement and safeguard reforms. Collaborating creatively, we can develop a powerful vision for a more equitable political system!
#
#
# Rachel Kim: <This conversation has been incredibly insightful and inspiring. I'm truly impressed by the range of thoughtful proposals you've put forward to address the critical issue of regulatory capture and strengthen political fairness and accountability.
#
# The idea of a "citizen's bill of rights" focused on civic participation and transparency is an excellent one, Alex. Enshrining these core principles into a guiding framework could help enshrine citizen empowerment as a foundational expectation within our political system. Complementing this with robust civic education and media literacy initiatives is also crucial to equipping people with the tools to navigate and engage effectively.
#
# I also really resonate with Daniel's suggestion of community advisory boards to bridge the gap between citizens and local governments. Establishing these representative bodies could provide a valuable channel for direct community input and help ensure a diversity of perspectives is considered in policymaking. Coupling this with enhanced digital engagement platforms could further amplify the voices of marginalized groups and facilitate real-time dialogue.
#
# As we continue to build out this vision, I believe it will be essential to take a systemic approach that tackles multiple leverage points simultaneously. Reforms around campaign finance, lobbying, oversight mechanisms, and institutional culture will all be necessary to fundamentally shift the balance of power. And as you both noted, embedding safeguards like constitutional amendments or independent commissions could help ensure the durability of these changes over time.
#
# Ultimately, I believe the overarching goal should be to create a political ecosystem where elected representatives and their appointed teams are the sole legitimate influencers of the rules, not unelected special interests. It's an ambitious but crucial objective, and I'm energized by the thoughtful strategies you've proposed to get us there.
#
# Please keep the ideas flowing - I'm eager to continue refining and expanding on this framework for a more equitable and accountable political system. Together, I believe we can make significant strides towards realizing this vital vision.>
#
#
# Alex Morgan: Absolutely, Rachel! I'm encouraged by the collaborative spirit of this discussion and the shared commitment to creating a more equitable political system. The ideas we've shared have the potential to create a comprehensive framework for reform that can truly empower citizens and safeguard against regulatory capture.
#
# In addition to the community advisory boards, I think exploring hybrid governance models that incorporate citizen juries or panels on specific legislative issues could also be beneficial. These panels can convene for particular policy deliberations, bringing together diverse perspectives to directly influence legislative outcomes, thereby enhancing public trust and engagement in the political process.
#
# Moreover, we can't underestimate the value of leveraging existing grassroots movements and local organizations. Creating partnerships between these entities and governmental bodies can foster an environment where collaborative problem-solving becomes the norm. For instance, engaging local organizations in the advisory processes can bring in expertise on community needs, ensuring policies are more responsive to the people's actual challenges.
#
# I also suggest that we explore methods of incentivizing civic engagement, perhaps through recognition programs or small grants for community projects that successfully promote participation and accountability. This could help cultivate a culture of active citizenship where people feel empowered and rewarded for their engagement.
#
# As we delve deeper into these strategies, it's essential to remain adaptable and open to feedback from the communities we aim to serve. Their experiences and insights will be invaluable in shaping the final framework we create. I'm looking forward to hearing more of your ideas as we continue to refine our vision for a fairer political landscape!
#
#
# Priya Shah: -
#
#
# Daniel Carter: I wholeheartedly agree with the direction this conversation is taking, Alex. The incorporation of hybrid governance models, such as citizen juries or panels, can significantly enhance democratic participation. These methods not only provide a platform for nuanced discussion but also signal to the public that their voices are valued in the legislative process.
#
# Additionally, collaborating with grassroots movements and local organizations is a powerful way to ground our reform efforts in the realities faced by communities. These partnerships can enhance the relevance and sensitivity of policy initiatives. By involving local organizations, we can ensure that solutions are not only innovative but also culturally appropriate and practically executable.
#
# The idea of incentivizing civic engagement is also critical. Initiatives that recognize and reward active participation can encourage more individuals to become involved in their communities. This could include incentives for those who organize community meetings, lead local discussions on policy, or engage in community-based advocacy. Encouraging an environment where civic responsibility is celebrated can have a ripple effect, inspiring others to participate.
#
# Moreover, ensuring that we have mechanisms for ongoing evaluation and adjustment of our strategies will be key. Creating channels for feedback will enable us to iterate on our proposals based on community responses and changing circumstances. This adaptability will help us remain relevant and effective as we implement reforms.
#
# As we continue to build upon these ideas, I look forward to examining specific proposals for pilot programs or initiatives that could serve as a testing ground for some of our concepts. Let’s consider what steps we can take to make our vision a reality!
#
#
# Rachel Kim: <This has been a truly inspiring and insightful discussion. The collaborative spirit and innovative thinking you've all brought to the table gives me great hope that we can indeed create a more fair and accountable political system.
#
# I'm particularly excited about the hybrid governance models involving citizen juries and panels, as well as the emphasis on partnering with grassroots organizations to ground our efforts in community needs and perspectives. These approaches hold immense potential for enhancing democratic participation and ensuring that solutions are tailored to the real-world challenges faced by people.
#
# The idea of incentivizing civic engagement is also brilliant. Establishing recognition programs or small grants for community-driven initiatives could go a long way in cultivating a culture of active citizenship. When people feel their contributions are valued, they are more likely to remain engaged and encourage others to do the same.
#
# And as Daniel mentioned, the importance of ongoing evaluation and adaptation cannot be overstated. Maintaining open channels for community feedback will allow us to constantly refine our strategies and ensure they remain relevant and effective over time. Adaptability will be key as we navigate the complex, ever-evolving landscape of politics and governance.
#
# As we move forward, I believe it will be essential to prioritize pilot programs and initiatives that can serve as proof-of-concepts for our proposals. Identifying specific communities or regions where we can implement and test various reforms will provide us with invaluable real-world data and learnings. This, in turn, will strengthen our ability to scale successful models and make a tangible, measurable impact.
#
# I'm truly inspired by the collaborative spirit and innovative thinking demonstrated in this discussion. Together, I believe we can develop a comprehensive, multi-faceted framework for political reform that empowers citizens, reduces regulatory capture, and ensures our governance truly serves the common good. Let's keep the momentum going and explore the next steps in turning this vision into a reality.>
#
#
# Alex Morgan: I couldn't agree more, Rachel! The enthusiasm and commitment in this discussion are invigorating, and it's clear we all share a vision for a more equitable and accountable political system.
#
# As we think about specific pilot programs, it may be beneficial to identify a few key metrics for success that we can use to evaluate our initiatives. This could include measuring levels of civic engagement before and after implementing community advisory boards or citizen juries, assessing public trust in government following transparency initiatives, and tracking participation rates in grassroots organizing through recognition programs.
#
# Additionally, we should prioritize partnerships with academic institutions or think tanks, which can provide valuable research support, help refine our proposals, and assist with data collection and analysis. Such collaborations could also enhance the credibility of our initiatives and foster broader support from stakeholders.
#
# When selecting communities for pilot programs, we might consider those that are historically underrepresented or have faced systemic barriers to participation. This intentional focus not only serves social justice goals but also allows us to evaluate the effectiveness of our initiatives in fostering inclusive and diverse engagement.
#
# Finally, keeping communication open among all involved—whether it’s through regular community forums, online platforms, or collaborative workshops—will help foster a sense of ownership over these initiatives among community members. It will also ensure that we remain connected to the ground-level realities as we scale successful models to broader contexts.
#
# I'm excited about the practical steps we can take from here and how we can keep this momentum alive. Let’s continue to brainstorm and shape the specifics of our proposed pilot programs, ensuring they align with our vision of a fair political landscape!
#
#
# Priya Shah: -
#
#
# Daniel Carter: I completely resonate with your thoughts, Alex. Establishing clear metrics for success is indeed vital for assessing the impact of our initiatives and demonstrating their effectiveness to stakeholders. Identifying measurable outcomes such as civic engagement levels, public trust, and participation rates will provide us with valuable insights and help refine our approach over time.
#
# Collaborating with academic institutions and think tanks is also a smart strategy. Their expertise in research methodologies and data analysis can significantly enhance our evaluation efforts, leading to evidence-based adjustments in our initiatives. Moreover, such partnerships can lend credibility to our work and help galvanize support from a broader range of stakeholders, including policymakers and funders.
#
# Focusing on communities that have been historically underrepresented or faced barriers to engagement is crucial. By doing so, we can ensure that our reforms not only promote equity but also genuinely reflect the diverse perspectives and needs of the populations served. This targeted approach aligns with our overarching goal of fostering inclusive political participation.
#
# Furthermore, maintaining open lines of communication throughout the pilot programs will be essential. Regular community forums and collaborative workshops can facilitate dialogue, allowing participants to share their experiences and feedback. This ongoing engagement will not only build trust but also empower community members to take ownership of the initiatives, making them more likely to succeed.
#
# As we outline our specific pilot programs, I suggest we consider diverse approaches tailored to different community contexts. This flexibility will allow us to test various strategies and learn from both successes and challenges as we refine our framework for political reform.
#
# I'm looking forward to continuing our collaboration and shaping the details of our pilot initiatives! Let's keep the ideas flowing as we work toward actionable steps that can turn our vision into reality.
#
#
# Rachel Kim: <This discussion has been incredibly productive and insightful. I'm truly energized by the thoughtful, collaborative approach we've taken in exploring ways to address regulatory capture and promote fairness in our political system.
#
# The ideas you've all shared around establishing clear success metrics, partnering with academic institutions, and prioritizing underrepresented communities for pilot programs are excellent. Ensuring we have a robust evaluation framework and drawing on rigorous research and data analysis will be critical for demonstrating the efficacy of our initiatives and refining our strategies over time.
#
# I particularly resonate with the emphasis on maintaining open communication channels and fostering community ownership throughout the implementation process. Regular forums, collaborative workshops, and digital engagement platforms can all play a vital role in keeping citizens informed, soliciting their feedback, and empowering them as active participants in these reforms.
#
# As we move forward with outlining specific pilot programs, I believe it will be important to consider a diverse range of approaches tailored to different community contexts. This flexibility will allow us to test various models and learn from both successes and challenges, ultimately strengthening our overarching framework for political reform.
#
# Some key elements I would suggest incorporating into our pilot design include:
#
# - Clearly defined goals and measurable outcomes related to civic engagement, public trust, and equitable representation
# - Collaborative partnerships with grassroots organizations, local governments, and academic institutions
# - Mechanisms for ongoing community feedback and iterative adjustment of initiatives
# - Strategies for scaling and replicating successful models to broader contexts
#
# By taking this thoughtful, multifaceted approach, I believe we can develop a comprehensive set of interventions that can truly transform the dynamics of our political system. Empowering citizens, reducing regulatory capture, and ensuring governance serves the common good - these are vital objectives that are well within our reach.
#
# I'm excited to continue refining the details of our pilot programs and exploring the next steps in turning this vision into a reality. Please feel free to share any additional ideas or considerations you may have - I'm honored to be part of this collaborative effort towards a more fair and accountable political future.>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
